# %% [markdown]
# ## **Scalability**, **Maintainability**, and **Reusability**
#
# ---
#
# ## 🔹 1. **Scalability**
#
# ### ➤ **Layman Meaning**:
#
# **Can your system grow and still work well?**
#
# ### 🧠 Think of it like:
#
# > "If your shop has 10 customers now and 1,000 later — can it still handle everyone without crashing?"
#
# ### 🛠 In software:
#
# * Can your app or system handle **more users, more data, more requests**?
# * Without slowing down or breaking?
#
# ### 📌 Example:
#
# Your **diabetes prediction web app** works well for 100 users.
# If tomorrow 10,000 people use it — **will it still run smoothly?**
# If yes → it's **scalable** ✅
#
# ---
#
# ## 🔹 2. **Maintainability**
#
# ### ➤ **Layman Meaning**:
#
# **Can you fix bugs and make changes easily?**
#
# ### 🧠 Think of it like:
#
# > "If something breaks in your machine, is it easy to open it, understand it, and repair it?"
#
# ### 🛠 In software:
#
# * Is your code **clean, organized, and easy to understand**?
# * Can someone else (or future-you) **quickly fix issues** or **add features**?
#
# ### 📌 Example:
#
# You made ASTRA ROBO. If a sensor stops working,
# Can you easily find where the bug is in code and fix it?
# If yes → your code is **maintainable** ✅
#
# ---
#
# ## 🔹 3. **Reusability**
#
# ### ➤ **Layman Meaning**:
#
# **Can you use the same part in another project without rewriting it?**
#
# ### 🧠 Think of it like:
#
# > "You made a piece of Lego that fits into many different toys."
#
# ### 🛠 In software:
#
# * Can you **use the same code, component, or module** in different apps?
# * Saves time, effort, and reduces bugs.
#
# ### 📌 Example:
#
# You wrote a Python function to **convert speech to text** for ASTRA ROBO.
# If you use that same function in another chatbot project → it's **reusable** ✅
#
# ---
#
# ## 🎯 Final Summary
#
# | Term                | Meaning in Simple Words               | Example                             |
# | ------------------- | ------------------------------------- | ----------------------------------- |
# | **Scalability**     | Can grow without crashing             | Web app handles more users/data     |
# | **Maintainability** | Easy to fix and improve               | Clean, understandable code          |
# | **Reusability**     | Use same part/code in multiple places | Use same speech-to-text in new apps |
#
# ---
